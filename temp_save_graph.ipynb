# %% [markdown]
# # temp save graph

# %% [markdown]
# ## ¿Qué hace este notebook?
#
# Es un **script utilitario** muy pequeño. Importa `build_graph` del módulo
# `langgraph_state_typed` (el script 01) y lo ejecuta para construir y guardar el grafo,
# lo que regenera el diagrama Mermaid `01_langgraph_state_typed.png`.
#
# Su única finalidad es reconstruir/guardar el grafo sin abrir el flujo interactivo del
# notebook 01.

# %% [markdown]
# ## Ejemplo de uso
#
# **Datos de interacción que espera el agente.** Ninguno: es un utilitario sin entrada ni
# pausa. Solo reconstruye y guarda el grafo del notebook 01.
#
# ```python
# # Requiere que 01_langgraph_state_typed defina build_graph y sea importable.
# from langgraph_state_typed import build_graph
# build_graph()                         # regenera 01_langgraph_state_typed.png
# ```

# %%
from langgraph_state_typed import build_graph

# %%
build_graph()
